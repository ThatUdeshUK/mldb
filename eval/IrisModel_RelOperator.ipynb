# %% [markdown]
# # Evaluate Python UDF Performance (Iris)

# %%
import os

import numpy as np
import pandas as pd

import json

import duckdb

from pprint import pprint

# %% [markdown]
# ### Load timing data

# %%
timing_dir = 'analyze_outputs'
files = [os.path.abspath(os.path.join(timing_dir, f)) for f in os.listdir(timing_dir) if '.json' in f]
files
# Out:
# ['/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_scalar_iris3_15000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris4_10000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec3_iris2_5000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_scalar_iris4_10000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec|w5-d512_iris3_1000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_scalar_iris5_5000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec|w5-d512_iris3_15000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris5_1000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec3_iris3_15000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris2_1000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec|w3-d128_iris3_10000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec3_iris3_10000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec|w3-d128_iris3_15000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec|w5-d512_iris3_10000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec3_iris3_5000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec|w3-d128_iris3_1000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_scalar_iris3_5000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_scalar_iris4_5000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_scalar_iris3_10000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris3_1000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris4_1000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_scalar_iris4_15000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris3_10000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris1_5000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris3_20000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_scalar_iris3_20000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec|w5-d512_iris3_20000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec3_iris3_20000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec|w3-d128_iris3_20000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_iris1_1000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_scalar_iris4_20000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec2_iris2_1000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris4_20000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec|w5-d512_iris3_5000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_scalar_iris5_1000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris5_5000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris2_5000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris5_20000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec3_iris2_1000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris1_20000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_scalar_iris5_20000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_scalar_iris3_1000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_scalar_iris4_1000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris3_5000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris4_5000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris2_20000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_iris1_10000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec2_iris2_20000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec3_iris2_20000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec|w3-d128_iris3_5000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec3_iris3_1000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec3_iris2_10000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec2_iris2_10000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris1_1000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_iris1_20000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris2_10000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_scalar_iris5_15000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_scalar_iris5_10000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris1_10000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec_iris5_10000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec2_iris2_5000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec3_iris2_15000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_iris1_5000000.json',
#  '/Users/udeshuk/Developer/mldb/eval/analyze_outputs/opt_vec2_iris2_15000000.json']

# %%
times_raw = {}

for file in files:
    with open(file, "r") as f:
        name = file.split("/")[-1].split(".")[0]
        workload = name.split("_")[-1]
        key = name.split("_iris")[0]
        run = name.split("_iris")[1][0]
        times_raw[key + "~" + workload + "~" + run] = json.loads(f.read())

# %%
times = []

for k, v in times_raw.items():
    t = {}
    t['dataset'] = 'iris'
    t['pipeline'] = k.split("~")[0]
    t['workload'] = k.split("~")[1]
    t['run'] = k.split("~")[2]

    if t['run'] ==  '1':
        prediction = v['children'][0]['children'][0]['children'][0]
    else:
        prediction = v['children'][0]['children'][0]
        # if t['pipeline'] == 'opt_vec2':
        #     print(t['workload'])
        #     pprint(prediction)
    t["predict"] = prediction['timing'] * 1000000
    t["load"] = 0
    move = prediction['children'][0]['children'][0]
    t["move"] = move['timing'] * 1000000
    
    times.append(t)

# %%
times_df = pd.DataFrame.from_records(times).loc[:, ['dataset', 'pipeline', 'workload', 'move', 'load', 'predict']]
times_df['workload'] = times_df['workload'].astype(int)
times_df.sort_values(['pipeline', 'workload'])
times_df
# Out:
#    dataset         pipeline  workload       move  load      predict
# 0     iris   opt_vec_scalar  15000000  1925467.0     0    8679695.0
# 1     iris          opt_vec  10000000  1060667.0     0   16912116.0
# 2     iris         opt_vec3   5000000  1041674.0     0    4511019.0
# 3     iris   opt_vec_scalar  10000000  1048125.0     0    5176771.0
# 4     iris  opt_vec|w5-d512   1000000   146129.0     0   23001825.0
# ..     ...              ...       ...        ...   ...          ...
# 59    iris          opt_vec  10000000  1051651.0     0   16775249.0
# 60    iris         opt_vec2   5000000   564841.0     0    7739211.0
# 61    iris         opt_vec3  15000000  2849155.0     0   14521084.0
# 62    iris              opt   5000000   586376.0     0  252963288.0
# 63    iris         opt_vec2  15000000  1951649.0     0   23390199.0
#
# [64 rows x 6 columns]

# %%
stro = pd.read_csv('sub_time_rel_opt.csv')
stro['move'] = stro['move'] + stro['move_rev']
stro = stro.drop(columns=['move_rev'])
stro['dataset'] = 'iris'
stro['pipeline'] = 'opt_vec_V3'

times_df = pd.concat([times_df, stro])

# %% [markdown]
# ### Write to times table

# %%
con = duckdb.connect("../test.db")
tables = con.sql(f"SHOW TABLES").df()
has_table = tables[tables.name == 'times'].shape[0] == 1
    
if not has_table:
    con.sql(f"CREATE TABLE times (dataset varchar, workload integer, move integer, load integer, predict integer, ts timestamp DEFAULT current_timestamp)")

con.sql(f"DELETE FROM times WHERE pipeline LIKE 'opt%'")
con.sql(f"INSERT INTO times (dataset, pipeline, workload, move, load, predict) SELECT * FROM times_df")
con.sql(f"SELECT * FROM times").show()
con.close()
# Out:
# ┌─────────┬──────────┬─────────┬───────┬───────────┬─────────────────────────┬───────────────┐
# │ dataset │ workload │  move   │ load  │  predict  │           ts            │   pipeline    │
# │ varchar │  int32   │  int32  │ int32 │   int32   │        timestamp        │    varchar    │
# ├─────────┼──────────┼─────────┼───────┼───────────┼─────────────────────────┼───────────────┤
# │ iris    │  1000000 │   66407 │ 11404 │    644862 │ 2024-04-16 15:39:06.832 │ duckdb_python │
# │ iris    │  1000000 │   69000 │ 14205 │    711004 │ 2024-04-16 15:39:13.889 │ duckdb_python │
# │ iris    │  1000000 │   87882 │ 15013 │    714544 │ 2024-04-16 15:39:37.287 │ duckdb_python │
# │ iris    │  1000000 │   66269 │ 14332 │    696981 │ 2024-04-16 15:39:42.694 │ duckdb_python │
# │ iris    │  1000000 │   75381 │ 14991 │    691012 │ 2024-04-16 15:39:54.801 │ duckdb_python │
# │ iris    │  5000000 │  328913 │ 15558 │   5179009 │ 2024-04-16 15:40:13.76  │ duckdb_python │
# │ iris    │  5000000 │  349613 │ 15064 │   2955772 │ 2024-04-16 15:40:30.815 │ duckdb_python │
# │ iris    │  5000000 │  322196 │ 15970 │   2999283 │ 2024-04-16 15:40:42.004 │ duckdb_python │
# │ iris    │  5000000 │  317910 │ 15293 │   3087172 │ 2024-04-16 15:40:57.448 │ duckdb_python │
# │ iris    │  5000000 │  337603 │ 14921 │   3006441 │ 2024-04-16 15:41:07.685 │ duckdb_python │
# │  ·      │     ·    │     ·   │     · │      ·    │            ·            │    ·          │
# │  ·      │     ·    │     ·   │     · │      ·    │            ·            │    ·          │
# │  ·      │     ·    │     ·   │     · │      ·    │            ·            │    ·          │
# │ iris    │ 10000000 │ 1051651 │     0 │  16775249 │ 2024-05-08 13:06:18.492 │ opt_vec       │
# │ iris    │  5000000 │  564841 │     0 │   7739211 │ 2024-05-08 13:06:18.492 │ opt_vec2      │
# │ iris    │ 15000000 │ 2849155 │     0 │  14521084 │ 2024-05-08 13:06:18.492 │ opt_vec3      │
# │ iris    │  5000000 │  586376 │     0 │ 252963288 │ 2024-05-08 13:06:18.492 │ opt           │
# │ iris    │ 15000000 │ 1951649 │     0 │  23390199 │ 2024-05-08 13:06:18.492 │ opt_vec2      │
# │ iris    │  1000000 │   21060 │ 24716 │    534324 │ 2024-05-08 13:06:18.492 │ opt_vec_V3    │
# │ iris    │  5000000 │  115323 │ 24716 │   2507371 │ 2024-05-08 13:06:18.492 │ opt_vec_V3    │
# │ iris    │ 10000000 │  221590 │ 24716 │   4952802 │ 2024-05-08 13:06:18.492 │ opt_vec_V3    │
# │ iris    │ 15000000 │  311175 │ 24716 │   7231544 │ 2024-05-08 13:06:18.492 │ opt_vec_V3    │
# │ iris    │ 20000000 │  428666 │ 24716 │  10071421 │ 2024-05-08 13:06:18.492 │ opt_vec_V3    │
# ├─────────┴──────────┴─────────┴───────┴───────────┴─────────────────────────┴───────────────┤
# │ 145 rows (20 shown)                                                              7 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
con.close()
