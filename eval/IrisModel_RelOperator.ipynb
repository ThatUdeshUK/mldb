# %% [markdown]
# # Evaluate Python UDF Performance (Iris)

# %%
import os

import pandas as pd

import json
import duckdb

# %% [markdown]
# ### Load timing data

# %%
timing_dir = 'analyze_outputs'
files = [os.path.abspath(os.path.join(timing_dir, f)) for f in os.listdir(timing_dir) if '.json' in f and any([(s in f) for s in ['onnx_i', 'torch_i', 'onnx_single', 'torch_single']])]
files
# Out:
# ['/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_single_iris4_5000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_iris5_10000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_iris5_10000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_iris3_10000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_single_iris3_5000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_single_iris5_15000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_iris3_15000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_iris5_15000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_iris4_20000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_iris5_20000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_single_iris3_15000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_iris3_20000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_single_iris4_5000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_single_iris4_1000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_single_iris4_15000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_single_iris5_20000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_iris5_5000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_iris4_15000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_single_iris5_5000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_single_iris4_20000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_single_iris5_10000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_single_iris5_20000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_single_iris5_1000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_iris4_5000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_iris4_20000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_iris4_15000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_iris5_1000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_single_iris4_1000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_single_iris3_5000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_iris4_1000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_single_iris4_10000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_single_iris4_15000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_single_iris5_10000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_iris4_10000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_single_iris5_5000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_single_iris3_10000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_iris3_10000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_iris4_5000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_iris4_10000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_single_iris5_15000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_iris5_15000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_iris3_5000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_iris5_1000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_single_iris3_20000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_iris3_1000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_single_iris5_1000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_single_iris3_1000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_iris5_5000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_single_iris3_15000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_iris3_20000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_iris4_1000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_iris3_1000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_single_iris4_10000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_single_iris3_1000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_iris5_20000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_single_iris4_20000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_torch_iris3_15000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_single_iris3_10000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_iris3_5000000.json',
#  '/u/antor/u13/ukumaras/Projects/mldb/eval/analyze_outputs/opt_vec_onnx_single_iris3_20000000.json']

# %%
times_raw = {}

for file in files:
    with open(file, "r") as f:
        name = file.split("/")[-1].split(".")[0]
        workload = name.split("_")[-1]
        key = name.split("_iris")[0]
        run = name.split("_iris")[1][0]
        times_raw[key + "~" + workload + "~" + run] = json.loads(f.read())

# %%
times = []

for k, v in times_raw.items():
    t = {}
    t['dataset'] = 'iris'
    t['pipeline'] = k.split("~")[0]
    t['workload'] = k.split("~")[1]
    t['run'] = k.split("~")[2]

    if t['run'] ==  '1':
        prediction = v['children'][0]['children'][0]['children'][0]
    else:
        prediction = v['children'][0]['children'][0]
    pred_info = prediction['extra_info'].split('|')[1:]
    for i in pred_info:
        kv = i.split(":")
        t[kv[0]] = kv[1]
    
    times.append(t)

# %%
times_df = pd.DataFrame.from_records(times).loc[:, ['dataset', 'pipeline', 'workload', 'move', 'load', 'predict']]
times_df['workload'] = times_df['workload'].astype(int)
times_df.sort_values(['pipeline', 'workload'])
times_df
# Out:
#    dataset              pipeline  workload    move    load  predict
# 0     iris   opt_vec_onnx_single   5000000  119684    7443  1491323
# 1     iris         opt_vec_torch  10000000  259892    5398  3543445
# 2     iris          opt_vec_onnx  10000000  295035    7196  2960334
# 3     iris         opt_vec_torch  10000000  280028    5362  3486194
# 4     iris   opt_vec_onnx_single   5000000  119771    9563  1568372
# 5     iris   opt_vec_onnx_single  15000000  356580    8027  4603015
# 6     iris          opt_vec_onnx  15000000  440942    7125  4144989
# 7     iris         opt_vec_torch  15000000  389370    4789  5301605
# 8     iris          opt_vec_onnx  20000000  586944    6867  5945266
# 9     iris         opt_vec_torch  20000000  520116    4238  6900531
# 10    iris   opt_vec_onnx_single  15000000  354492    7724  4653930
# 11    iris          opt_vec_onnx  20000000  585265    6929  5845568
# 12    iris  opt_vec_torch_single   5000000  130560    4366  1822029
# 13    iris  opt_vec_torch_single   1000000   26184    4976   363726
# 14    iris   opt_vec_onnx_single  15000000  357897    7814  4534356
# 15    iris   opt_vec_onnx_single  20000000  472086    7776  6047039
# 16    iris         opt_vec_torch   5000000  129958    4337  1699455
# 17    iris         opt_vec_torch  15000000  389762    4408  5170461
# 18    iris   opt_vec_onnx_single   5000000  120415    7416  1545347
# 19    iris  opt_vec_torch_single  20000000  520196    5055  7239291
# 20    iris  opt_vec_torch_single  10000000  273847    4796  3437211
# 21    iris  opt_vec_torch_single  20000000  522376    5296  7279162
# 22    iris   opt_vec_onnx_single   1000000   24232    7711   312670
# 23    iris         opt_vec_torch   5000000  130035    4788  1761465
# 24    iris         opt_vec_torch  20000000  520559    4564  6862953
# 25    iris          opt_vec_onnx  15000000  445773    6931  4471207
# 26    iris         opt_vec_torch   1000000   26070    4693   364071
# 27    iris   opt_vec_onnx_single   1000000   24126    8405   311796
# 28    iris  opt_vec_torch_single   5000000  135958    5561  1814152
# 29    iris         opt_vec_torch   1000000   32930    4977   445979
# 30    iris   opt_vec_onnx_single  10000000  239114    7467  2920723
# 31    iris  opt_vec_torch_single  15000000  391602    4987  5461609
# 32    iris   opt_vec_onnx_single  10000000  237979   11064  3078931
# 33    iris         opt_vec_torch  10000000  260123    4423  3550676
# 34    iris  opt_vec_torch_single   5000000  130137    4769  1813696
# 35    iris  opt_vec_torch_single  10000000  280619    4599  3758103
# 36    iris          opt_vec_onnx  10000000  291314    6464  2913934
# 37    iris          opt_vec_onnx   5000000  149297    6609  1488976
# 38    iris          opt_vec_onnx  10000000  297714    6794  2963361
# 39    iris  opt_vec_torch_single  15000000  391751    5229  5494986
# 40    iris          opt_vec_onnx  15000000  442051    6951  4451642
# 41    iris         opt_vec_torch   5000000  150454    4989  1813620
# 42    iris          opt_vec_onnx   1000000   29869    6980   299249
# 43    iris  opt_vec_torch_single  20000000  532703    5435  7454804
# 44    iris          opt_vec_onnx   1000000   28988  167089   304919
# 45    iris  opt_vec_torch_single   1000000   26249    5342   365846
# 46    iris   opt_vec_onnx_single   1000000   24308   48806   322867
# 47    iris          opt_vec_onnx   5000000  147321    6779  1490414
# 48    iris  opt_vec_torch_single  15000000  434082    4521  5745221
# 49    iris         opt_vec_torch  20000000  520905    5063  6764857
# 50    iris          opt_vec_onnx   1000000   29747    7119   301849
# 51    iris         opt_vec_torch   1000000   81074  156920   609454
# 52    iris  opt_vec_torch_single  10000000  260506    4730  3669375
# 53    iris  opt_vec_torch_single   1000000   79458  103515   684988
# 54    iris          opt_vec_onnx  20000000  585101    6809  5918012
# 55    iris   opt_vec_onnx_single  20000000  476365    7804  6203521
# 56    iris         opt_vec_torch  15000000  391075    5315  5324020
# 57    iris   opt_vec_onnx_single  10000000  237036    7920  3111006
# 58    iris          opt_vec_onnx   5000000  145162    8474  1511698
# 59    iris   opt_vec_onnx_single  20000000  472593    7834  6184991

# %%
times_df = pd.concat([times_df])

# %% [markdown]
# ### Write to times table

# %%
con = duckdb.connect("../test.db")
tables = con.sql(f"SHOW TABLES").df()
has_table = tables[tables.name == 'times'].shape[0] == 1
    
if not has_table:
    con.sql(f"CREATE TABLE times (dataset varchar, workload integer, move integer, load integer, predict integer, ts timestamp DEFAULT current_timestamp)")

con.sql(f"DELETE FROM times WHERE pipeline LIKE 'opt%'")
con.sql(f"INSERT INTO times (dataset, pipeline, workload, move, load, predict) SELECT * FROM times_df")
con.sql(f"SELECT * FROM times").show()
con.close()
# Out:
# ┌─────────┬──────────────────────┬──────────┬─────────┬────────┬──────────┬─────────────────────────┐
# │ dataset │       pipeline       │ workload │  move   │  load  │ predict  │           ts            │
# │ varchar │       varchar        │  int32   │  int32  │ int32  │  int32   │        timestamp        │
# ├─────────┼──────────────────────┼──────────┼─────────┼────────┼──────────┼─────────────────────────┤
# │ iris    │ python_udf_vec       │  1000000 │  218034 │  13971 │  2139728 │ 2024-05-21 14:43:26.063 │
# │ iris    │ python_udf_vec       │  5000000 │ 1185950 │  14044 │  5536022 │ 2024-05-21 14:43:54.855 │
# │ iris    │ python_udf_vec       │ 10000000 │ 2224030 │  13889 │  7646142 │ 2024-05-21 14:49:48.529 │
# │ iris    │ python_udf_vec       │ 15000000 │ 3188160 │  13680 │ 11789199 │ 2024-05-21 14:50:06.5   │
# │ iris    │ python_udf_vec       │ 20000000 │ 4314927 │  15031 │ 14350052 │ 2024-05-21 14:50:28.176 │
# │ iris    │ python_udf_vec       │  1000000 │  223791 │  14497 │  1715185 │ 2024-05-21 14:50:33.186 │
# │ iris    │ python_udf_vec       │  5000000 │ 1095444 │  14399 │  5390325 │ 2024-05-21 14:50:42.858 │
# │ iris    │ python_udf_vec       │ 10000000 │ 2147617 │  14101 │  8948654 │ 2024-05-21 14:50:57.766 │
# │ iris    │ python_udf_vec       │ 15000000 │ 3173435 │  14991 │ 11166434 │ 2024-05-21 14:51:15.275 │
# │ iris    │ python_udf_vec       │ 20000000 │ 4222857 │  14943 │ 14202884 │ 2024-05-21 14:51:37.02  │
# │  ·      │      ·               │     ·    │     ·   │     ·  │      ·   │           ·             │
# │  ·      │      ·               │     ·    │     ·   │     ·  │      ·   │           ·             │
# │  ·      │      ·               │     ·    │     ·   │     ·  │      ·   │           ·             │
# │ iris    │ opt_vec_onnx         │  1000000 │   29747 │   7119 │   301849 │ 2024-05-22 00:38:40.579 │
# │ iris    │ opt_vec_torch        │  1000000 │   81074 │ 156920 │   609454 │ 2024-05-22 00:38:40.579 │
# │ iris    │ opt_vec_torch_single │ 10000000 │  260506 │   4730 │  3669375 │ 2024-05-22 00:38:40.579 │
# │ iris    │ opt_vec_torch_single │  1000000 │   79458 │ 103515 │   684988 │ 2024-05-22 00:38:40.579 │
# │ iris    │ opt_vec_onnx         │ 20000000 │  585101 │   6809 │  5918012 │ 2024-05-22 00:38:40.579 │
# │ iris    │ opt_vec_onnx_single  │ 20000000 │  476365 │   7804 │  6203521 │ 2024-05-22 00:38:40.579 │
# │ iris    │ opt_vec_torch        │ 15000000 │  391075 │   5315 │  5324020 │ 2024-05-22 00:38:40.579 │
# │ iris    │ opt_vec_onnx_single  │ 10000000 │  237036 │   7920 │  3111006 │ 2024-05-22 00:38:40.579 │
# │ iris    │ opt_vec_onnx         │  5000000 │  145162 │   8474 │  1511698 │ 2024-05-22 00:38:40.579 │
# │ iris    │ opt_vec_onnx_single  │ 20000000 │  472593 │   7834 │  6184991 │ 2024-05-22 00:38:40.579 │
# ├─────────┴──────────────────────┴──────────┴─────────┴────────┴──────────┴─────────────────────────┤
# │ 90 rows (20 shown)                                                                      7 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
con.close()
